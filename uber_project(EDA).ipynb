# %% [markdown]
# <a href="https://colab.research.google.com/github/Farahesmail/project/blob/main/uber_project(EDA).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt


data=pd.read_csv('final_internship_data.csv')

# %%
data.shape
# Out:
# (500000, 26)

# %%
data.columns
#pickup datetime as same as (hour,day,weekday,month,year)
# Out:
# Index(['User ID', 'User Name', 'Driver Name', 'Car Condition', 'Weather',
#        'Traffic Condition', 'key', 'fare_amount', 'pickup_datetime',
#        'pickup_longitude', 'pickup_latitude', 'dropoff_longitude',
#        'dropoff_latitude', 'passenger_count', 'hour', 'day', 'month',
#        'weekday', 'year', 'jfk_dist', 'ewr_dist', 'lga_dist', 'sol_dist',
#        'nyc_dist', 'distance', 'bearing'],
#       dtype='object')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500000 entries, 0 to 499999
# Data columns (total 26 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   User ID            500000 non-null  object
#  1   User Name          500000 non-null  object
#  2   Driver Name        500000 non-null  object
#  3   Car Condition      500000 non-null  object
#  4   Weather            500000 non-null  object
#  5   Traffic Condition  500000 non-null  object
#  6   key                500000 non-null  object
#  7   fare_amount        500000 non-null  float64
#  8   pickup_datetime    500000 non-null  object
#  9   pickup_longitude   500000 non-null  float64
#  10  pickup_latitude    500000 non-null  float64
#  11  dropoff_longitude  499995 non-null  float64
#  12  dropoff_latitude   499995 non-null  float64
#  13  passenger_count    500000 non-null  int64
#  14  hour               500000 non-null  int64
# ...

# %%
data.isnull().sum()
# Out:
# User ID              0
# User Name            0
# Driver Name          0
# Car Condition        0
# Weather              0
# Traffic Condition    0
# key                  0
# fare_amount          0
# pickup_datetime      0
# pickup_longitude     0
# pickup_latitude      0
# dropoff_longitude    5
# dropoff_latitude     5
# passenger_count      0
# hour                 0
# day                  0
# month                0
# weekday              0
# year                 0
# jfk_dist             5
# ewr_dist             5
# lga_dist             5
# sol_dist             5
# nyc_dist             5
# distance             5
# bearing              5
# dtype: int64

# %%
data.describe()
#fare amount with negative values
#distance is zero
#passenger count is zero
# Out:
#          fare_amount  pickup_longitude  pickup_latitude  dropoff_longitude  \
# count  500000.000000     500000.000000    500000.000000      499995.000000
# mean       11.358361         -1.265712         0.696740          -1.265755
# std         9.916617          0.206941         0.140909           0.205903
# min       -44.900000        -52.119764       -54.389440         -59.049665
# 25%         6.000000         -1.291405         0.710958          -1.291393
# 50%         8.500000         -1.291226         0.711268          -1.291197
# 75%        12.500000         -1.290970         0.711520          -1.290908
# max       500.000000         37.360538        29.724576           0.712985
#
#        dropoff_latitude  passenger_count           hour            day  \
# count     499995.000000    500000.000000  500000.000000  500000.000000
# mean           0.696675         1.683428      13.510834      15.684206
# std            0.128997         1.307395       6.511571       8.681066
# ...

# %%
plt.figure(figsize=(8, 5))
sns.countplot(data=data, x='passenger_count')
plt.title('Distribution of Passenger Counts', fontsize=15)
plt.xlabel('Number of Passengers', fontsize=12)
plt.ylabel('Count', fontsize=12)

plt.figure(figsize=(8, 5))
sns.countplot(data=data, x='hour')
plt.title('Distribution of hours', fontsize=15)
plt.xlabel('HOUR', fontsize=12)
plt.ylabel('Count', fontsize=12)

plt.figure(figsize=(8, 5))
sns.countplot(data=data, x='day')
plt.title('Distribution of days', fontsize=15)
plt.xlabel('DAY', fontsize=12)
plt.ylabel('Count', fontsize=12)

plt.figure(figsize=(8, 5))
sns.countplot(data=data, x='weekday')
plt.title('Distribution of weekdays', fontsize=15)
plt.xlabel('WEEKDAY', fontsize=12)
plt.ylabel('Count', fontsize=12)

plt.figure(figsize=(8, 5))
sns.countplot(data=data, x='month')
plt.title('Distribution of month', fontsize=15)
plt.xlabel('MONTH', fontsize=12)
plt.ylabel('Count', fontsize=12)


plt.figure(figsize=(8, 5))
sns.countplot(data=data, x='year')
plt.title('Distribution of years', fontsize=15)
plt.xlabel('YEAR', fontsize=12)
plt.ylabel('Count', fontsize=12)

plt.figure(figsize=(8, 5))
sns.countplot(data=data, x='Weather')
plt.title('Distribution of weather status', fontsize=15)
plt.xlabel('weather', fontsize=12)
plt.ylabel('Count', fontsize=12)


plt.figure(figsize=(8, 5))
sns.countplot(data=data, x='Car Condition')
plt.title('Distribution of car condition', fontsize=15)
plt.xlabel('car condition', fontsize=12)
plt.ylabel('Count', fontsize=12)


plt.show()

# %%
plt.figure(figsize=(10, 5))
sns.histplot(data['fare_amount'], kde=True, bins=30, color='red')
plt.title('Distribution of Fare Amounts')
plt.xlabel('Fare Amount ($)')
plt.ylabel('Number of Trips')
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(data=data, x='Weather', y='Traffic Condition', alpha=0.5)
plt.title('Relationship: Weather vs Traffic Condition')
plt.xlabel('Weather')
plt.ylabel('Traffic Condition')
plt.show()

# %%
sns.countplot(x="Weather", hue="Traffic Condition", data=data)
# Out:
# <Axes: xlabel='Weather', ylabel='count'>

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(data=data, x='Weather', y='distance', alpha=0.5)
plt.title('Relationship: Weather vs distance')
plt.xlabel('Weather')
plt.ylabel('distance')
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(data=data, x='Traffic Condition', y='distance', alpha=0.5)
plt.title('Relationship: Traffic Condition vs distance')
plt.xlabel('Traffic Condition')
plt.ylabel('distance')
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(data=data, x='distance', y='fare_amount', alpha=0.5)
plt.title('Relationship: distance vs fare_amount')
plt.xlabel('distance')
plt.ylabel('fare_amount')
plt.show()
#maybe distance calculated wrong

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(data=data, x='Car Condition', y='distance', alpha=0.5)
plt.title('Relationship: Car Condition vs distance')
plt.xlabel('Car Condition')
plt.ylabel('distance')
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(data=data, x='Traffic Condition', y='fare_amount', alpha=0.5)
plt.title('Relationship: Traffic Condition vs fare_amount')
plt.xlabel('Traffic Condition')
plt.ylabel('fare_amount')
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(data=data, x='Weather', y='fare_amount', alpha=0.5)
plt.title('Relationship: Weather vs fare_amount')
plt.xlabel('Weather')
plt.ylabel('fare_amount')
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(data=data, x='Car Condition', y='fare_amount', alpha=0.5)
plt.title('Relationship: Car Condition vs fare_amount')
plt.xlabel('Car Condition')
plt.ylabel('fare_amount')
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(data=data, x='passenger_count', y='fare_amount', alpha=0.5)
plt.title('Relationship: passengers vs fare_amount')
plt.xlabel('passengers number')
plt.ylabel('fare_amount')
plt.show()

# %%
plt.figure(figsize=(12, 6))
sns.scatterplot(data=data, x='weekday', y='fare_amount', alpha=0.3)
plt.title('Raw Relation: weekday vs Fare Amount')
# Out:
# Text(0.5, 1.0, 'Raw Relation: weekday vs Fare Amount')

# %%
plt.figure(figsize=(12, 6))
sns.scatterplot(data=data, x='hour', y='Traffic Condition', alpha=0.3)
plt.title('Raw Relation: hour vs Traffic Condition')
# Out:
# Text(0.5, 1.0, 'Raw Relation: hour vs Traffic Condition')

# %%
plt.figure(figsize=(10, 5))
sns.lineplot(data=data, x='hour', y='fare_amount')
plt.title('Average Fare Amount by Hour of Day')
plt.xticks(range(0, 24))
plt.grid(True)

# %%
plt.figure(figsize=(10,8))

scatter = plt.scatter(
    data["pickup_longitude"],
    data["pickup_latitude"],
    c=data["fare_amount"],             # color = fare
    s=data["jfk_dist"]*3,              # size = airport distance
    cmap="viridis",
    alpha=0.6
)

plt.colorbar(scatter, label="Fare Amount")
plt.xlabel("Pickup Longitude")
plt.ylabel("Pickup Latitude")
plt.title("Pickup Location vs JFK Distance vs Fare Amount")

plt.show()

# %%
plt.figure(figsize=(10,8))

scatter = plt.scatter(
    data["pickup_longitude"],
    data["pickup_latitude"],
    c=data["fare_amount"],             # color = fare
    s=data["ewr_dist"]*3,              # size = airport distance
    cmap="viridis",
    alpha=0.6
)

plt.colorbar(scatter, label="Fare Amount")
plt.xlabel("Pickup Longitude")
plt.ylabel("Pickup Latitude")
plt.title("Pickup Location vs ewr Distance vs Fare Amount")

plt.show()

# %%
plt.figure(figsize=(10,8))

scatter = plt.scatter(
    data["pickup_longitude"],
    data["pickup_latitude"],
    c=data["fare_amount"],             # color = fare
    s=data["nyc_dist"]*3,              # size = airport distance
    cmap="viridis",
    alpha=0.6
)

plt.colorbar(scatter, label="Fare Amount")
plt.xlabel("Pickup Longitude")
plt.ylabel("Pickup Latitude")
plt.title("Pickup Location vs nyc Distance vs Fare Amount")

plt.show()

# %%
plt.figure(figsize=(10,8))

scatter = plt.scatter(
    data["pickup_longitude"],
    data["pickup_latitude"],
    c=data["fare_amount"],             # color = fare
    s=data["lga_dist"]*3,              # size = airport distance
    cmap="viridis",
    alpha=0.6
)

plt.colorbar(scatter, label="Fare Amount")
plt.xlabel("Pickup Longitude")
plt.ylabel("Pickup Latitude")
plt.title("Pickup Location vs lga Distance vs Fare Amount")

plt.show()

# %%
plt.figure(figsize=(10,8))

scatter = plt.scatter(
    data["pickup_longitude"],
    data["pickup_latitude"],
    c=data["fare_amount"],             # color = fare
    s=data["sol_dist"]*3,              # size = airport distance
    cmap="viridis",
    alpha=0.6
)

plt.colorbar(scatter, label="Fare Amount")
plt.xlabel("Pickup Longitude")
plt.ylabel("Pickup Latitude")
plt.title("Pickup Location vs sol Distance vs Fare Amount")

plt.show()

# %%
import numpy as np

def haversine(lat1, lon1, lat2, lon2):
    R = 6371  # نصف قطر الأرض بالكيلومتر

    lat1 = np.radians(lat1)
    lon1 = np.radians(lon1)
    lat2 = np.radians(lat2)
    lon2 = np.radians(lon2)

    dlat = lat2 - lat1
    dlon = lon2 - lon1

    a = np.sin(dlat/2)**2 + np.cos(lat1) * np.cos(lat2) * np.sin(dlon/2)**2
    c = 2 * np.arcsin(np.sqrt(a))

    return R * c

data["calculated_distance_km"] = haversine(
    data["pickup_latitude"],
    data["pickup_longitude"],
    data["dropoff_latitude"],
    data["dropoff_longitude"]
)

data["calculated_distance_km"].describe()
# Out:
# count    499995.000000
# mean          0.446480
# std          18.385653
# min           0.000000
# 25%           0.024080
# 50%           0.041655
# 75%           0.074669
# max        8463.154030
# Name: calculated_distance_km, dtype: float64

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(data=data, x='calculated_distance_km', y='fare_amount', alpha=0.5)
plt.title('Relationship: distance vs fare_amount')
plt.xlabel('distance')
plt.ylabel('fare_amount')
plt.show()
